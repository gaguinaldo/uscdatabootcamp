# %%
import pandas as pd
import json
import requests as r
from twitter_keys import Consumer_Key, Consumer_API_Secret, Access_Token, Access_Token_Secret
import tweepy 
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
# %matplotlib inline

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

auth = tweepy.OAuthHandler(Consumer_Key, Consumer_API_Secret)
auth.set_access_token(Access_Token, Access_Token_Secret)

#If no parser is defined, then it seems that the wrapper will work with the straight text.
api = tweepy.API(auth)

# %%
target_user = 'garyvee'

public_tweets = api.user_timeline(target_user)
public_tweets

#Able to print tweets
for tweet in public_tweets:
    print (tweet.text)
# Out:
# Understand this https://t.co/BNKtZAiAP5
# https://t.co/LVIkJ9VjJh
# @timskye @AnthonyBaird Yup looking that entire platform over this holiday
# @steveplunkett @QuoteGaryVee Houston @NickDiodato u should come by for vip
# Are you a street fashion clothing brand? If so are you looking to do smart creative for social with athletes? If so… https://t.co/XEk6LdA2p3
# @Jkemp23 Yes @WineLib_BW
# Any businesses leaders in Houston area?
#
# Cc @NickDiodato
# https://t.co/3pJTIulN91
#
# 2018 Grammy Nominee for Best Rap/Sung Performance Talking Through His Next Move | DailyV… https://t.co/9QXllglbr6
# Love that! @vaynersports https://t.co/EQs390SoFj
# Fire https://t.co/IQnkWbseDI
# https://t.co/3pJTIulN91
#
# 2018 Grammy Nominee for Best Rap Performance GoldLink Talking Through His Next Moves | Da… https://t.co/a0G63WLnur
# Any large businesses or entrepreneurs in Texas or surrounding states? I’m coming to Houston for a talk in Feb but h… https://t.co/ysSjPGYw6u
# ...

# %%
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
public_tweets = api.user_timeline(target_user)

#Returns a JSON object that needs to be manually parsed
public_tweets
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Dec 18 23:54:58 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/BNKtZAiAP5',
#      'expanded_url': 'https://twitter.com/garyvee/status/942906063938088960/video/1',
#      'id': 942905998024388608,
#      'id_str': '942905998024388608',
#      'indices': [16, 39],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/942905998024388608/pu/img/1YaSK4MeUCw8zTBG.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/942905998024388608/pu/img/1YaSK4MeUCw8zTBG.jpg',
#      'sizes': {'large': {'h': 960, 'resize': 'fit', 'w': 960},
#       'medium': {'h': 960, 'resize': 'fit', 'w': 960},
#       'small': {'h': 680, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/BNKtZAiAP5'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
# ...

# %%
#Look for tweet times

#Each index is a different tweet
type(public_tweets[0]['created_at'])
# Out:
# str

# %%
tweet_time = []

for tweet in public_tweets:
    tweet_time.append(tweet['created_at'])
tweet_time
# Out:
# ['Mon Dec 18 23:54:58 +0000 2017',
#  'Mon Dec 18 23:48:03 +0000 2017',
#  'Mon Dec 18 20:54:10 +0000 2017',
#  'Mon Dec 18 20:42:07 +0000 2017',
#  'Mon Dec 18 20:08:17 +0000 2017',
#  'Mon Dec 18 19:43:42 +0000 2017',
#  'Mon Dec 18 19:07:27 +0000 2017',
#  'Mon Dec 18 19:03:39 +0000 2017',
#  'Mon Dec 18 18:26:20 +0000 2017',
#  'Mon Dec 18 18:12:55 +0000 2017',
#  'Mon Dec 18 17:53:16 +0000 2017',
#  'Mon Dec 18 15:24:05 +0000 2017',
#  'Mon Dec 18 14:47:33 +0000 2017',
#  'Mon Dec 18 14:16:54 +0000 2017',
#  'Mon Dec 18 11:12:11 +0000 2017',
#  'Mon Dec 18 02:13:41 +0000 2017',
#  'Mon Dec 18 01:58:03 +0000 2017',
#  'Mon Dec 18 01:54:22 +0000 2017',
#  'Sun Dec 17 23:35:57 +0000 2017',
#  'Sun Dec 17 23:02:30 +0000 2017']

# %%
clean_date_time = []
for time_ in tweet_time:
    clean_date_time.append(datetime.strptime(time_, '%a %b %d %H:%M:%S %z %Y'))
# Out:
# [datetime.datetime(2017, 12, 18, 23, 54, 58, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2017, 12, 18, 23, 48, 3, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2017, 12, 18, 20, 54, 10, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2017, 12, 18, 20, 42, 7, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2017, 12, 18, 20, 8, 17, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2017, 12, 18, 19, 43, 42, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2017, 12, 18, 19, 7, 27, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2017, 12, 18, 19, 3, 39, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2017, 12, 18, 18, 26, 20, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2017, 12, 18, 18, 12, 55, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2017, 12, 18, 17, 53, 16, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2017, 12, 18, 15, 24, 5, tzinfo=datetime.timezone.utc),
# ...

# %%
format_date_time = []
for time_ in clean_date_time:
    format_date_time.append(time_.strftime("%Y-%m-%d %H:%M:%S"))

# %%
delta = clean_date_time[0] - clean_date_time[1]
delta
# Out:
# datetime.timedelta(0, 415)
