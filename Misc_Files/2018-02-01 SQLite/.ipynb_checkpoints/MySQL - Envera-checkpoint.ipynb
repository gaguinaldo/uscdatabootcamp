# %%
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
import pandas as pd
from config import *

# %%
connection_string = 'mysql://grantaguinaldo:Olinda96788@gta1.cw2vngcs70cl.us-west-2.rds.amazonaws.com:3306/nat_questions'
engine = create_engine(connection_string)
conn = engine.connect()

# %%
data = pd.read_sql("SELECT * FROM questions", conn)

# %%
data
# Out:
#      id                                           question
# 0     1               What is the supreme law of the land?
# 1     2                     What does the Constitution do?
# 2     3  The idea of self-government is in the first th...
# 3     4                              What is an amendment?
# 4     5  What do we call the first ten amendments to th...
# 5     6  What is one right or freedom from the First Am...
# 6     7    How many amendments does the Constitution have?
# 7     8       What did the Declaration of Independence do?
# 8     9  What are two rights in the Declaration of Inde...
# 9    10                       What is freedom of religion?
# 10   11  What is the economic system in the United States?
# 11   12                         What is the ?rule of law??
# 12   13         Name one branch or part of the government.
# 13   14  What stops one branch of government from becom...
# 14   15          Who is in charge of the executive branch?
# 15   16                            Who makes federal laws?
# 16   17       What are the two parts of the U.S. Congress?
# 17   18                  How many U.S. Senators are there?
# 18   19        We elect a U.S. Senator for how many years?
# 19   20      Who is one of your state?s U.S. Senators now?
# 20   21  The House of Representatives has how many voti...
# 21   22  We elect a U.S. Representative for how many ye...
# 22   23                     Name your U.S. Representative.
# 23   24                 Who does a U.S. Senator represent?
# 24   25  Why do some states have more Representatives t...
# 25   26           We elect a President for how many years?
# 26   27            In what month do we vote for President?
# 27   28  What is the name of the President of the Unite...
# 28   29  What is the name of the Vice President of the ...
# 29   30  If the President can no longer serve, who beco...
# ..  ...                                                ...
# 70   71  What territory did the United States buy from ...
# 71   72  Name one war fought by the United States in th...
# 72   73  Name the U.S. war between the North and the So...
# 73   74        Name one problem that led to the Civil War.
# 74   75  What was one important thing that Abraham Linc...
# 75   76         What did the Emancipation Proclamation do?
# 76   77                      What did Susan B. Anthony do?
# 77   78  Name one war fought by the United States in th...
# 78   79              Who was President during World War I?
# 79   80  Who was President during the Great Depression ...
# 80   81   Who did the United States fight in World War II?
# 81   82  Before he was President, Eisenhower was a gene...
# 82   83  During the Cold War, what was the main concern...
# 83   84  What movement tried to end racial discrimination?
# 84   85               What did Martin Luther King, Jr. do?
# 85   86  What major event happened on September 11, 200...
# 86   87  Name one American Indian tribe in the United S...
# 87   88  Name one of the two longest rivers in the Unit...
# 88   89  What ocean is on the West Coast of the United ...
# 89   90  What ocean is on the East Coast of the United ...
# 90   91                           Name one U.S. territory.
# 91   92                Name one state that borders Canada.
# 92   93                Name one state that borders Mexico.
# 93   94          What is the capital of the United States?
# 94   95                    Where is the Statue of Liberty?
# 95   96                 Why does the flag have 13 stripes?
# 96   97                   Why does the flag have 50 stars?
# 97   98           What is the name of the national anthem?
# 98   99             When do we celebrate Independence Day?
# 99  100                    Name two national U.S. holidays
#
# [100 rows x 2 columns]
