# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

import keras
from keras.preprocessing import image
from keras.applications.xception import (
    Xception, preprocess_input, decode_predictions)
# Out:
# Using TensorFlow backend.

# %%
# Load the Xception model
# https://keras.io/applications/#xception

model = Xception(include_top=True, weights='imagenet')

# %%
# Default Image Size for Xception
image_size = (224, 224)

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("Images", "kitten.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)

# %%
# Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
# Make predictions
predictions = model.predict(x)
print('Predicted: ', decode_predictions(predictions, top=5)[0])
plt.imshow(img)
# Out:
# Predicted:  [('n02123045', 'tabby', 0.51815742), ('n02123159', 'tiger_cat', 0.33598509), ('n02124075', 'Egyptian_cat', 0.10962788), ('n02127052', 'lynx', 0.017951336), ('n04589890', 'window_screen', 0.0046330313)]

# %%
# Refactor above steps into reusable function
