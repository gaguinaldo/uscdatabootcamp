# %% [markdown]
# ## Grant Aguinaldo, HW-6 Submission
#
# ### Observations
#
# Point 1.
#
# Point 2.
#
# Point 3.
#
# ### Approach to solving problem.
#
#
#
# ***
#
# ## Unit 6 | Assignment - What's the Weather Like?
#
# ## Background
#
# Whether financial, political, or social -- data's true power lies in its ability to answer questions definitively. So let's take what you've learned about Python requests, APIs, and JSON traversals to answer a fundamental question: "What's the weather like as we approach the equator?"
#
# Now, we know what you may be thinking: _"Duh. It gets hotter..."_
#
# But, if pressed, how would you **prove** it?
#
# ## WeatherPy
#
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api), and a little common sense to create a representative model of weather across world cities.
#
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# Your final notebook must:
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * Include a print log of each city as it's being processed with the city number, city name, and requested URL.
# * Save both a CSV of all data retrieved and png images for each scatter plot.
#
# As final considerations:
#
# * You must use the Matplotlib and Seaborn libraries.
# * You must include a written description of three observable trends based on the data.
# * You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
# * You must include an exported markdown version of your Notebook called  `README.md` in your GitHub repository.
# * See [Example Solution](WeatherPy_Example.pdf) for a reference on expected format.
#
# ## Hints and Considerations
#
# * You may want to start this assignment by refreshing yourself on 4th grade geography, in particular, the [geographic coordinate system](http://desktop.arcgis.com/en/arcmap/10.3/guide-books/map-projections/about-geographic-coordinate-systems.htm).
#
# * Next, spend the requisite time necessary to study the OpenWeatherMap API. Based on your initial study, you should be able to answer  basic questions about the API: Where do you request the API key? Which Weather API in particular will you need? What URL endpoints does it expect? What JSON structure does it respond with? Before you write a line of code, you should be aiming to have a crystal clear understanding of your intended outcome.
#
# * Though we've never worked with the [citipy Python library](https://pypi.python.org/pypi/citipy), push yourself to decipher how it works, and why it might be relevant. Before you try to incorporate the library into your analysis, start by creating simple test cases outside your main script to confirm that you are using it correctly. Too often, when introduced to a new library, students get bogged down by the most minor of errors -- spending hours investigating their entire code -- when, in fact, a simple and focused test would have shown their basic utilization of the library was wrong from the start. Don't let this be you!
#
# * Part of our expectation in this challenge is that you will use critical thinking skills to understand how and why we're recommending the tools we are. What is Citipy for? Why would you use it in conjunction with the OpenWeatherMap API? How would you do so?
#
# * In building your script, pay attention to the cities you are using in your query pool. Are you getting coverage of the full gamut of latitudes and longitudes? Or are you simply choosing 500 cities concentrated in one region of the world? Even if you were a geographic genius, simply rattling 500 cities based on your human selection would create a biased dataset. Be thinking of how you should counter this. (Hint: Consider the full range of latitudes).
#
# * Lastly, remember -- this is a challenging activity. Push yourself! If you complete this task, then you can safely say that you've gained a strong mastery of the core foundations of data analytics and it will only go better from here. Good luck!

# %%
#Standard imports

import pandas as pd
import requests as r
import json
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline

# %%
# Point to csv file containing city ID

file = 'cityid.csv'

# %%
#Load in CSV file into Pandas

df = pd.read_csv(file, encoding='utf-8', low_memory=False)

# %%
#Select a random sample of 500 cities into pandas and store values in a list. 
city_list = df.sample(500).reset_index()['id'].tolist()

#Set up API url using end point and key.
url = 'http://api.openweathermap.org/data/2.5/weather?id='
api_key = '&APPID=0c715aff73757bce5f32aba6da14fd45'
units = '&units=imperial'

#Generate list of all end points based on city id.
url_list = [(url + str(city) + units + api_key) for city in city_list]

#Genearte a dictionary of city ID and end point.
url_dict = {'city_id': city_list, 'url': url_list}

#Load resulting dictionary into Pandas
city_df = pd.DataFrame(url_dict)

# %%
#Add columns to dataframe

city_df['city'] = ''
city_df['country'] = ''
city_df['lat'] = ''
city_df['lon'] = ''
city_df['temp'] = ''
city_df['wind'] = ''
city_df['clouds'] = ''
city_df['humidity'] = ''

# %%
#Display head of dataframe

city_df.shape
# Out:
# (500, 10)

# %%
#Confirm that city id in url matches the city id from dataframe

city_df['url'][4]
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?id=295370&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45'

# %%
#Confirm that city id in url matches the city id from dataframe

city_df.iloc[4]
# Out:
# city_id                                                295370
# url         http://api.openweathermap.org/data/2.5/weather...
# city
# country
# lat
# lon
# temp
# wind
# clouds
# humidity
# Name: 4, dtype: object

# %%
#Set up loop to ping end point and return values from json

#Set up for loop to loop through dataframe
i = 0
print('------Start Collecting Data------')
for index, row in city_df.iterrows():
    response = r.get(row['url']).json()    
#     print(response)
    date_time_now = datetime.datetime.now()
    #now.strftime("%Y-%m-%d %H:%M")
    print('Record ' + str(i+1) + ' ' + 'Collected at: ' + date_time_now.strftime("%Y-%m-%d %H:%M"))
    print('City Name: ' + response['name'] + ', ' + 'Country Name: ' + response['sys']['country'])
    print(row['url'])
    print('--------------')

#Set up try/except blocks to populate dataframe based on structure of json    
    try:
        city_df.set_value(index, "city", response['name'])
        city_df.set_value(index, 'country', response['sys']['country'])
        city_df.set_value(index, 'lat', response['coord']['lat'])
        city_df.set_value(index, 'lon', response['coord']['lon'])
        city_df.set_value(index, 'temp', response['main']['temp_max'])
        city_df.set_value(index, 'wind', response['wind']['speed'])
        city_df.set_value(index, 'clouds', response['clouds']['all'])
        city_df.set_value(index, 'humidity', response['main']['humidity'])
    except:
        print("Missing field... skipping.")
    i += 1
print('------End Collecting Data------')
# Out:
# ------Start Collecting Data------
# Record 1 Collected at: 2018-02-15 15:27
# City Name: Gunnedah, Country Name: AU
# http://api.openweathermap.org/data/2.5/weather?id=2164206&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 2 Collected at: 2018-02-15 15:27
# City Name: Stanislaw Dolny, Country Name: PL
# http://api.openweathermap.org/data/2.5/weather?id=3085019&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 3 Collected at: 2018-02-15 15:27
# City Name: Strandby, Country Name: DK
# http://api.openweathermap.org/data/2.5/weather?id=2612274&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 4 Collected at: 2018-02-15 15:27
# City Name: Laucha, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2880228&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 5 Collected at: 2018-02-15 15:27
# City Name: Dabburiya, Country Name: IL
# http://api.openweathermap.org/data/2.5/weather?id=295370&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 6 Collected at: 2018-02-15 15:27
# City Name: Pieve di Cadore, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3170754&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 7 Collected at: 2018-02-15 15:27
# City Name: Itigi, Country Name: TZ
# http://api.openweathermap.org/data/2.5/weather?id=158904&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 8 Collected at: 2018-02-15 15:27
# City Name: Dubai, Country Name: AE
# http://api.openweathermap.org/data/2.5/weather?id=292223&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 9 Collected at: 2018-02-15 15:27
# City Name: Sinuapa, Country Name: HN
# http://api.openweathermap.org/data/2.5/weather?id=3601282&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 10 Collected at: 2018-02-15 15:27
# City Name: Zhaoyuan, Country Name: CN
# http://api.openweathermap.org/data/2.5/weather?id=1784953&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 11 Collected at: 2018-02-15 15:27
# City Name: Villa Vasquez, Country Name: DO
# http://api.openweathermap.org/data/2.5/weather?id=3491905&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 12 Collected at: 2018-02-15 15:27
# City Name: Riola Sardo, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=2523613&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 13 Collected at: 2018-02-15 15:27
# City Name: Odolo, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3172115&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 14 Collected at: 2018-02-15 15:27
# City Name: Specchia, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=2523030&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 15 Collected at: 2018-02-15 15:27
# City Name: Ar Raqqah, Country Name: SY
# http://api.openweathermap.org/data/2.5/weather?id=172955&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 16 Collected at: 2018-02-15 15:27
# City Name: Saint-Gildas-des-Bois, Country Name: FR
# http://api.openweathermap.org/data/2.5/weather?id=2979680&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 17 Collected at: 2018-02-15 15:27
# City Name: Bagra, Country Name: IN
# http://api.openweathermap.org/data/2.5/weather?id=1277863&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 18 Collected at: 2018-02-15 15:27
# City Name: Winchester, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4313697&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 19 Collected at: 2018-02-15 15:27
# City Name: Suvorovskaya, Country Name: RU
# http://api.openweathermap.org/data/2.5/weather?id=485871&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 20 Collected at: 2018-02-15 15:27
# City Name: Westerland, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2810284&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 21 Collected at: 2018-02-15 15:27
# City Name: Deerfield, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5085369&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 22 Collected at: 2018-02-15 15:27
# City Name: Grandwood Park, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4894360&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 23 Collected at: 2018-02-15 15:27
# City Name: Krokom, Country Name: SE
# http://api.openweathermap.org/data/2.5/weather?id=2699176&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 24 Collected at: 2018-02-15 15:27
# City Name: Ottery Saint Mary, Country Name: GB
# http://api.openweathermap.org/data/2.5/weather?id=2640834&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 25 Collected at: 2018-02-15 15:27
# City Name: Brentwood, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5110077&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 26 Collected at: 2018-02-15 15:27
# City Name: Bockhorn, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2947316&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 27 Collected at: 2018-02-15 15:27
# City Name: Kljuc, Country Name: BA
# http://api.openweathermap.org/data/2.5/weather?id=3198050&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 28 Collected at: 2018-02-15 15:27
# City Name: Cairo, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4234985&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 29 Collected at: 2018-02-15 15:27
# City Name: Zharkent, Country Name: KZ
# http://api.openweathermap.org/data/2.5/weather?id=1520253&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 30 Collected at: 2018-02-15 15:27
# City Name: Talavera de la Reina, Country Name: ES
# http://api.openweathermap.org/data/2.5/weather?id=2510693&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 31 Collected at: 2018-02-15 15:27
# City Name: Cison di Valmarino, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3178636&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 32 Collected at: 2018-02-15 15:27
# City Name: Downton, Country Name: GB
# http://api.openweathermap.org/data/2.5/weather?id=2651020&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 33 Collected at: 2018-02-15 15:27
# City Name: Conyngham, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5185289&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 34 Collected at: 2018-02-15 15:27
# City Name: Malkinia Gorna, Country Name: PL
# http://api.openweathermap.org/data/2.5/weather?id=765328&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 35 Collected at: 2018-02-15 15:27
# City Name: Kbely, Country Name: CZ
# http://api.openweathermap.org/data/2.5/weather?id=3073743&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 36 Collected at: 2018-02-15 15:27
# City Name: Womelsdorf, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5219972&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 37 Collected at: 2018-02-15 15:27
# City Name: Trevignano Romano, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3165205&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 38 Collected at: 2018-02-15 15:27
# City Name: Campo do Brito, Country Name: BR
# http://api.openweathermap.org/data/2.5/weather?id=3467780&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 39 Collected at: 2018-02-15 15:27
# City Name: Aguachica, Country Name: CO
# http://api.openweathermap.org/data/2.5/weather?id=3690465&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 40 Collected at: 2018-02-15 15:27
# City Name: Bayawan, Country Name: PH
# http://api.openweathermap.org/data/2.5/weather?id=1725804&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 41 Collected at: 2018-02-15 15:27
# City Name: Emba, Country Name: CY
# http://api.openweathermap.org/data/2.5/weather?id=146639&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 42 Collected at: 2018-02-15 15:27
# City Name: Monsheim, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2869752&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 43 Collected at: 2018-02-15 15:27
# City Name: Tutubigan, Country Name: PH
# http://api.openweathermap.org/data/2.5/weather?id=1680566&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 44 Collected at: 2018-02-15 15:27
# City Name: Saint Andrews, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4597499&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 45 Collected at: 2018-02-15 15:27
# City Name: Pamukova, Country Name: TR
# http://api.openweathermap.org/data/2.5/weather?id=740729&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 46 Collected at: 2018-02-15 15:27
# City Name: Guitiriz, Country Name: ES
# http://api.openweathermap.org/data/2.5/weather?id=3120928&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 47 Collected at: 2018-02-15 15:27
# City Name: Indian Rocks Beach, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4159675&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 48 Collected at: 2018-02-15 15:27
# City Name: Yapeyu, Country Name: AR
# http://api.openweathermap.org/data/2.5/weather?id=3427279&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 49 Collected at: 2018-02-15 15:27
# City Name: Theix, Country Name: FR
# http://api.openweathermap.org/data/2.5/weather?id=2972979&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 50 Collected at: 2018-02-15 15:27
# City Name: Caserta, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3179866&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 51 Collected at: 2018-02-15 15:27
# City Name: Piape I, Country Name: PH
# http://api.openweathermap.org/data/2.5/weather?id=1693987&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 52 Collected at: 2018-02-15 15:27
# City Name: Preobrazhenka, Country Name: UA
# http://api.openweathermap.org/data/2.5/weather?id=696348&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 53 Collected at: 2018-02-15 15:27
# City Name: Norden, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2862118&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 54 Collected at: 2018-02-15 15:27
# City Name: Kaeng Khro, Country Name: TH
# http://api.openweathermap.org/data/2.5/weather?id=1610505&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 55 Collected at: 2018-02-15 15:27
# City Name: Palencia, Country Name: ES
# http://api.openweathermap.org/data/2.5/weather?id=3114531&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 56 Collected at: 2018-02-15 15:27
# City Name: Jiquipilas, Country Name: MX
# http://api.openweathermap.org/data/2.5/weather?id=3526488&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 57 Collected at: 2018-02-15 15:27
# City Name: Adro, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3183461&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 58 Collected at: 2018-02-15 15:27
# City Name: Itamaraju, Country Name: BR
# http://api.openweathermap.org/data/2.5/weather?id=3460826&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 59 Collected at: 2018-02-15 15:27
# City Name: Workum, Country Name: NL
# http://api.openweathermap.org/data/2.5/weather?id=2744179&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 60 Collected at: 2018-02-15 15:27
# City Name: Bois-dArcy, Country Name: FR
# http://api.openweathermap.org/data/2.5/weather?id=3032064&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 61 Collected at: 2018-02-15 15:27
# City Name: Altamira, Country Name: BR
# http://api.openweathermap.org/data/2.5/weather?id=3407882&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 62 Collected at: 2018-02-15 15:27
# City Name: Ciorasti, Country Name: RO
# http://api.openweathermap.org/data/2.5/weather?id=681664&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 63 Collected at: 2018-02-15 15:27
# City Name: Lanycsok, Country Name: HU
# http://api.openweathermap.org/data/2.5/weather?id=3048963&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 64 Collected at: 2018-02-15 15:27
# City Name: Pitimbu, Country Name: BR
# http://api.openweathermap.org/data/2.5/weather?id=3391889&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 65 Collected at: 2018-02-15 15:27
# City Name: Balocawehay, Country Name: PH
# http://api.openweathermap.org/data/2.5/weather?id=1727929&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 66 Collected at: 2018-02-15 15:27
# City Name: Saint-Hilaire-de-Talmont, Country Name: FR
# http://api.openweathermap.org/data/2.5/weather?id=2979539&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 67 Collected at: 2018-02-15 15:27
# City Name: Aulnay-sous-Bois, Country Name: FR
# http://api.openweathermap.org/data/2.5/weather?id=3036145&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 68 Collected at: 2018-02-15 15:27
# City Name: Glenfield, Country Name: AU
# http://api.openweathermap.org/data/2.5/weather?id=2165326&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 69 Collected at: 2018-02-15 15:27
# City Name: Vila Nova de Milfontes, Country Name: PT
# http://api.openweathermap.org/data/2.5/weather?id=2261617&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 70 Collected at: 2018-02-15 15:27
# City Name: San Ignacio, Country Name: HN
# http://api.openweathermap.org/data/2.5/weather?id=3602257&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 71 Collected at: 2018-02-15 15:27
# City Name: Kasserine, Country Name: TN
# http://api.openweathermap.org/data/2.5/weather?id=2473457&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 72 Collected at: 2018-02-15 15:27
# City Name: Petroupolis, Country Name: GR
# http://api.openweathermap.org/data/2.5/weather?id=255377&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 73 Collected at: 2018-02-15 15:27
# City Name: Abergavenny, Country Name: GB
# http://api.openweathermap.org/data/2.5/weather?id=2657815&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 74 Collected at: 2018-02-15 15:27
# City Name: Mohnesee, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=3207377&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 75 Collected at: 2018-02-15 15:27
# City Name: Dobropolye, Country Name: UA
# http://api.openweathermap.org/data/2.5/weather?id=709900&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 76 Collected at: 2018-02-15 15:27
# City Name: Spisska Nova Ves, Country Name: SK
# http://api.openweathermap.org/data/2.5/weather?id=723526&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 77 Collected at: 2018-02-15 15:27
# City Name: Machacamarca, Country Name: BO
# http://api.openweathermap.org/data/2.5/weather?id=3910971&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 78 Collected at: 2018-02-15 15:27
# City Name: Tankara, Country Name: IN
# http://api.openweathermap.org/data/2.5/weather?id=1254972&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 79 Collected at: 2018-02-15 15:27
# City Name: Grumello del Monte, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3175752&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 80 Collected at: 2018-02-15 15:27
# City Name: Victoria, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4739157&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 81 Collected at: 2018-02-15 15:27
# City Name: Tando Allahyar, Country Name: PK
# http://api.openweathermap.org/data/2.5/weather?id=1163965&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 82 Collected at: 2018-02-15 15:27
# City Name: Gay, Country Name: RU
# http://api.openweathermap.org/data/2.5/weather?id=561731&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 83 Collected at: 2018-02-15 15:27
# City Name: Tokyo, Country Name: JP
# http://api.openweathermap.org/data/2.5/weather?id=1850147&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 84 Collected at: 2018-02-15 15:27
# City Name: Tonning, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2821878&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 85 Collected at: 2018-02-15 15:27
# City Name: Henstedt-Ulzburg, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=3209083&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 86 Collected at: 2018-02-15 15:27
# City Name: Rector, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4127973&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 87 Collected at: 2018-02-15 15:27
# City Name: Quincy-Voisins, Country Name: FR
# http://api.openweathermap.org/data/2.5/weather?id=2984677&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 88 Collected at: 2018-02-15 15:27
# City Name: Rostovka, Country Name: RU
# http://api.openweathermap.org/data/2.5/weather?id=1493523&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 89 Collected at: 2018-02-15 15:27
# City Name: Australind, Country Name: AU
# http://api.openweathermap.org/data/2.5/weather?id=2077454&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 90 Collected at: 2018-02-15 15:27
# City Name: Groeningen, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2917107&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 91 Collected at: 2018-02-15 15:27
# City Name: Bouake, Country Name: CI
# http://api.openweathermap.org/data/2.5/weather?id=2290956&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 92 Collected at: 2018-02-15 15:27
# City Name: Serenje, Country Name: ZM
# http://api.openweathermap.org/data/2.5/weather?id=898912&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 93 Collected at: 2018-02-15 15:27
# City Name: Maracas, Country Name: BR
# http://api.openweathermap.org/data/2.5/weather?id=3457854&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 94 Collected at: 2018-02-15 15:27
# City Name: Marilia, Country Name: BR
# http://api.openweathermap.org/data/2.5/weather?id=3457692&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 95 Collected at: 2018-02-15 15:27
# City Name: Sarinena, Country Name: ES
# http://api.openweathermap.org/data/2.5/weather?id=3109380&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 96 Collected at: 2018-02-15 15:27
# City Name: Buyukcavuslu, Country Name: TR
# http://api.openweathermap.org/data/2.5/weather?id=750228&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 97 Collected at: 2018-02-15 15:27
# City Name: Oroville, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5379759&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 98 Collected at: 2018-02-15 15:27
# City Name: Pattensen, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2855243&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 99 Collected at: 2018-02-15 15:27
# City Name: Lumut, Country Name: MY
# http://api.openweathermap.org/data/2.5/weather?id=1735450&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 100 Collected at: 2018-02-15 15:27
# City Name: SeaTac, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5809805&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 101 Collected at: 2018-02-15 15:27
# City Name: Kangani, Country Name: KM
# http://api.openweathermap.org/data/2.5/weather?id=921847&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 102 Collected at: 2018-02-15 15:27
# City Name: Nagymanyok, Country Name: HU
# http://api.openweathermap.org/data/2.5/weather?id=3047622&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 103 Collected at: 2018-02-15 15:27
# City Name: Cacu, Country Name: BR
# http://api.openweathermap.org/data/2.5/weather?id=3468352&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 104 Collected at: 2018-02-15 15:27
# City Name: Fyli, Country Name: GR
# http://api.openweathermap.org/data/2.5/weather?id=262426&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 105 Collected at: 2018-02-15 15:27
# City Name: Bliss Corner, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4930804&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 106 Collected at: 2018-02-15 15:27
# City Name: Ladera Ranch, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5364199&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 107 Collected at: 2018-02-15 15:27
# City Name: Ceplenita, Country Name: RO
# http://api.openweathermap.org/data/2.5/weather?id=682407&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 108 Collected at: 2018-02-15 15:27
# City Name: Istria, Country Name: RO
# http://api.openweathermap.org/data/2.5/weather?id=675471&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 109 Collected at: 2018-02-15 15:27
# City Name: Amato, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=2525725&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 110 Collected at: 2018-02-15 15:27
# City Name: Dublin, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4687151&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 111 Collected at: 2018-02-15 15:27
# City Name: Tete, Country Name: MZ
# http://api.openweathermap.org/data/2.5/weather?id=1026014&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 112 Collected at: 2018-02-15 15:27
# City Name: Limni, Country Name: GR
# http://api.openweathermap.org/data/2.5/weather?id=258306&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 113 Collected at: 2018-02-15 15:27
# City Name: Winter Park, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4178560&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 114 Collected at: 2018-02-15 15:27
# City Name: Los Mochis, Country Name: MX
# http://api.openweathermap.org/data/2.5/weather?id=3997479&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 115 Collected at: 2018-02-15 15:27
# City Name: Chakapara, Country Name: IN
# http://api.openweathermap.org/data/2.5/weather?id=1348753&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 116 Collected at: 2018-02-15 15:27
# City Name: Lengenfeld, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2878852&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 117 Collected at: 2018-02-15 15:27
# City Name: La Grange, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4297238&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 118 Collected at: 2018-02-15 15:27
# City Name: Huyton, Country Name: GB
# http://api.openweathermap.org/data/2.5/weather?id=2646329&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 119 Collected at: 2018-02-15 15:27
# City Name: Wagga Wagga, Country Name: AU
# http://api.openweathermap.org/data/2.5/weather?id=2145110&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 120 Collected at: 2018-02-15 15:27
# City Name: Berkeley, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4884562&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 121 Collected at: 2018-02-15 15:27
# City Name: Fussgonheim, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2923503&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 122 Collected at: 2018-02-15 15:27
# City Name: Onokhoy, Country Name: RU
# http://api.openweathermap.org/data/2.5/weather?id=2018436&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 123 Collected at: 2018-02-15 15:27
# City Name: Commack, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5113412&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 124 Collected at: 2018-02-15 15:27
# City Name: Lipayran, Country Name: PH
# http://api.openweathermap.org/data/2.5/weather?id=1706034&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 125 Collected at: 2018-02-15 15:27
# City Name: Cysoing, Country Name: FR
# http://api.openweathermap.org/data/2.5/weather?id=3021935&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 126 Collected at: 2018-02-15 15:27
# City Name: Konigsfeld im Schwarzwald, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2885888&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 127 Collected at: 2018-02-15 15:27
# City Name: Corrales, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5463237&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 128 Collected at: 2018-02-15 15:27
# City Name: Santa Venetia, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5393384&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 129 Collected at: 2018-02-15 15:27
# City Name: Mountain Home Air Force Base, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=7261929&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 130 Collected at: 2018-02-15 15:27
# City Name: Pomarico, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3170350&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 131 Collected at: 2018-02-15 15:27
# City Name: Al Jamaliyah, Country Name: EG
# http://api.openweathermap.org/data/2.5/weather?id=361029&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 132 Collected at: 2018-02-15 15:27
# City Name: Branca, Country Name: PT
# http://api.openweathermap.org/data/2.5/weather?id=2742024&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 133 Collected at: 2018-02-15 15:27
# City Name: Salacgriva, Country Name: LV
# http://api.openweathermap.org/data/2.5/weather?id=455910&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 134 Collected at: 2018-02-15 15:27
# City Name: Tiszavasvari, Country Name: HU
# http://api.openweathermap.org/data/2.5/weather?id=714692&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 135 Collected at: 2018-02-15 15:27
# City Name: Hattersheim, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2909240&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 136 Collected at: 2018-02-15 15:27
# City Name: Vartej, Country Name: IN
# http://api.openweathermap.org/data/2.5/weather?id=1253381&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 137 Collected at: 2018-02-15 15:27
# City Name: Vilkija, Country Name: LT
# http://api.openweathermap.org/data/2.5/weather?id=593144&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 138 Collected at: 2018-02-15 15:27
# City Name: Racines, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3169646&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 139 Collected at: 2018-02-15 15:27
# City Name: Solhan, Country Name: TR
# http://api.openweathermap.org/data/2.5/weather?id=300377&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 140 Collected at: 2018-02-15 15:27
# City Name: Rot, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2844579&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 141 Collected at: 2018-02-15 15:27
# City Name: Bad Rothenfelde, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2953367&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 142 Collected at: 2018-02-15 15:27
# City Name: Fountainebleau, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4156091&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 143 Collected at: 2018-02-15 15:27
# City Name: Radevormwald, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2850995&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 144 Collected at: 2018-02-15 15:27
# City Name: Velikent, Country Name: RU
# http://api.openweathermap.org/data/2.5/weather?id=476106&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 145 Collected at: 2018-02-15 15:27
# City Name: Valletta, Country Name: MT
# http://api.openweathermap.org/data/2.5/weather?id=2562305&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 146 Collected at: 2018-02-15 15:27
# City Name: Seignosse, Country Name: FR
# http://api.openweathermap.org/data/2.5/weather?id=2975273&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 147 Collected at: 2018-02-15 15:27
# City Name: Oak Hills Place, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4335754&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 148 Collected at: 2018-02-15 15:27
# City Name: Phak Hai, Country Name: TH
# http://api.openweathermap.org/data/2.5/weather?id=1607865&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 149 Collected at: 2018-02-15 15:27
# City Name: Apatlaco, Country Name: MX
# http://api.openweathermap.org/data/2.5/weather?id=3532808&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 150 Collected at: 2018-02-15 15:27
# City Name: Manapa, Country Name: PH
# http://api.openweathermap.org/data/2.5/weather?id=1702083&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 151 Collected at: 2018-02-15 15:27
# City Name: Hjallerup, Country Name: DK
# http://api.openweathermap.org/data/2.5/weather?id=2620275&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 152 Collected at: 2018-02-15 15:27
# City Name: Bayt Fajjar, Country Name: PS
# http://api.openweathermap.org/data/2.5/weather?id=284341&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 153 Collected at: 2018-02-15 15:27
# City Name: Malhargarh, Country Name: IN
# http://api.openweathermap.org/data/2.5/weather?id=1264099&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 154 Collected at: 2018-02-15 15:27
# City Name: Santa Lucia di Piave, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3218581&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 155 Collected at: 2018-02-15 15:27
# City Name: Golega, Country Name: PT
# http://api.openweathermap.org/data/2.5/weather?id=2267624&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 156 Collected at: 2018-02-15 15:27
# City Name: Holzwickede, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2899538&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 157 Collected at: 2018-02-15 15:27
# City Name: Norway, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5004016&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 158 Collected at: 2018-02-15 15:27
# City Name: Jujutla, Country Name: SV
# http://api.openweathermap.org/data/2.5/weather?id=3585392&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 159 Collected at: 2018-02-15 15:27
# City Name: Tsurusaki, Country Name: JP
# http://api.openweathermap.org/data/2.5/weather?id=1849561&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 160 Collected at: 2018-02-15 15:27
# City Name: Diest, Country Name: BE
# http://api.openweathermap.org/data/2.5/weather?id=2799397&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 161 Collected at: 2018-02-15 15:27
# City Name: Barwala, Country Name: IN
# http://api.openweathermap.org/data/2.5/weather?id=1276815&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 162 Collected at: 2018-02-15 15:27
# City Name: San Zenone al Lambro, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3167160&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 163 Collected at: 2018-02-15 15:27
# City Name: Seacliff, Country Name: AU
# http://api.openweathermap.org/data/2.5/weather?id=2078451&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 164 Collected at: 2018-02-15 15:27
# City Name: Maizuru, Country Name: JP
# http://api.openweathermap.org/data/2.5/weather?id=1857766&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 165 Collected at: 2018-02-15 15:27
# City Name: Hedaru, Country Name: TZ
# http://api.openweathermap.org/data/2.5/weather?id=159647&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 166 Collected at: 2018-02-15 15:27
# City Name: Jewett City, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4836993&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 167 Collected at: 2018-02-15 15:27
# City Name: Poydras, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4337963&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 168 Collected at: 2018-02-15 15:27
# City Name: Huruesti, Country Name: RO
# http://api.openweathermap.org/data/2.5/weather?id=675901&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 169 Collected at: 2018-02-15 15:27
# City Name: Campos Gerais, Country Name: BR
# http://api.openweathermap.org/data/2.5/weather?id=3467680&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 170 Collected at: 2018-02-15 15:27
# City Name: Xiangtan, Country Name: CN
# http://api.openweathermap.org/data/2.5/weather?id=1790492&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 171 Collected at: 2018-02-15 15:27
# City Name: Ventimiglia di Sicilia, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=2522787&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 172 Collected at: 2018-02-15 15:27
# City Name: Inniswold, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4328435&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 173 Collected at: 2018-02-15 15:27
# City Name: Saint-Melaine-sur-Aubance, Country Name: FR
# http://api.openweathermap.org/data/2.5/weather?id=2978065&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 174 Collected at: 2018-02-15 15:27
# City Name: Carpina, Country Name: BR
# http://api.openweathermap.org/data/2.5/weather?id=3402721&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 175 Collected at: 2018-02-15 15:27
# City Name: Vara, Country Name: SE
# http://api.openweathermap.org/data/2.5/weather?id=2665018&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 176 Collected at: 2018-02-15 15:27
# City Name: Dangcalan, Country Name: PH
# http://api.openweathermap.org/data/2.5/weather?id=1715719&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 177 Collected at: 2018-02-15 15:27
# City Name: Peshtera, Country Name: BG
# http://api.openweathermap.org/data/2.5/weather?id=728317&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 178 Collected at: 2018-02-15 15:27
# City Name: Soissons, Country Name: FR
# http://api.openweathermap.org/data/2.5/weather?id=2974389&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 179 Collected at: 2018-02-15 15:27
# City Name: San Lorenzo Tlacotepec, Country Name: MX
# http://api.openweathermap.org/data/2.5/weather?id=3827030&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 180 Collected at: 2018-02-15 15:27
# City Name: Lunca de Jos, Country Name: RO
# http://api.openweathermap.org/data/2.5/weather?id=674419&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 181 Collected at: 2018-02-15 15:27
# City Name: Mullica Hill, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4503195&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 182 Collected at: 2018-02-15 15:28
# City Name: Riva Ligure, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3169267&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 183 Collected at: 2018-02-15 15:28
# City Name: Gloversville, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5118743&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 184 Collected at: 2018-02-15 15:28
# City Name: Uniara, Country Name: IN
# http://api.openweathermap.org/data/2.5/weather?id=1253751&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 185 Collected at: 2018-02-15 15:28
# City Name: San Nicolas, Country Name: HN
# http://api.openweathermap.org/data/2.5/weather?id=3601834&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 186 Collected at: 2018-02-15 15:28
# City Name: Tiruchchendur, Country Name: IN
# http://api.openweathermap.org/data/2.5/weather?id=1254390&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 187 Collected at: 2018-02-15 15:28
# City Name: Vulturesti, Country Name: RO
# http://api.openweathermap.org/data/2.5/weather?id=662394&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 188 Collected at: 2018-02-15 15:28
# City Name: Pitkyaranta, Country Name: RU
# http://api.openweathermap.org/data/2.5/weather?id=509234&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 189 Collected at: 2018-02-15 15:28
# City Name: Puerto Lleras, Country Name: CO
# http://api.openweathermap.org/data/2.5/weather?id=3671424&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 190 Collected at: 2018-02-15 15:28
# City Name: Gualaco, Country Name: HN
# http://api.openweathermap.org/data/2.5/weather?id=3609389&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 191 Collected at: 2018-02-15 15:28
# City Name: Torrejon de la Calzada, Country Name: ES
# http://api.openweathermap.org/data/2.5/weather?id=3107783&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 192 Collected at: 2018-02-15 15:28
# City Name: Redlynch, Country Name: AU
# http://api.openweathermap.org/data/2.5/weather?id=2151886&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 193 Collected at: 2018-02-15 15:28
# City Name: Solt, Country Name: HU
# http://api.openweathermap.org/data/2.5/weather?id=3045303&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 194 Collected at: 2018-02-15 15:28
# City Name: Rozborz, Country Name: PL
# http://api.openweathermap.org/data/2.5/weather?id=760237&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 195 Collected at: 2018-02-15 15:28
# City Name: Turinskaya Sloboda, Country Name: RU
# http://api.openweathermap.org/data/2.5/weather?id=1488931&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 196 Collected at: 2018-02-15 15:28
# City Name: Katsuta, Country Name: JP
# http://api.openweathermap.org/data/2.5/weather?id=2112312&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 197 Collected at: 2018-02-15 15:28
# City Name: Jackson, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5031678&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 198 Collected at: 2018-02-15 15:28
# City Name: Gluckstadt, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2919763&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 199 Collected at: 2018-02-15 15:28
# City Name: Kathmandu, Country Name: NP
# http://api.openweathermap.org/data/2.5/weather?id=1283240&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 200 Collected at: 2018-02-15 15:28
# City Name: Stonehaven, Country Name: GB
# http://api.openweathermap.org/data/2.5/weather?id=2636814&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 201 Collected at: 2018-02-15 15:28
# City Name: Dulag, Country Name: PH
# http://api.openweathermap.org/data/2.5/weather?id=1714264&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 202 Collected at: 2018-02-15 15:28
# City Name: Avion, Country Name: FR
# http://api.openweathermap.org/data/2.5/weather?id=3035667&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 203 Collected at: 2018-02-15 15:28
# City Name: Qibye, Country Name: PS
# http://api.openweathermap.org/data/2.5/weather?id=282348&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 204 Collected at: 2018-02-15 15:28
# City Name: Andalsnes, Country Name: NO
# http://api.openweathermap.org/data/2.5/weather?id=3163155&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 205 Collected at: 2018-02-15 15:28
# City Name: Douglas, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5823516&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 206 Collected at: 2018-02-15 15:28
# City Name: Kumru, Country Name: TR
# http://api.openweathermap.org/data/2.5/weather?id=742238&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 207 Collected at: 2018-02-15 15:28
# City Name: Finneytown, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4511642&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 208 Collected at: 2018-02-15 15:28
# City Name: Petrila, Country Name: RO
# http://api.openweathermap.org/data/2.5/weather?id=670969&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 209 Collected at: 2018-02-15 15:28
# City Name: Magdalena Contreras, Country Name: MX
# http://api.openweathermap.org/data/2.5/weather?id=3523760&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 210 Collected at: 2018-02-15 15:28
# City Name: Thakurganj, Country Name: IN
# http://api.openweathermap.org/data/2.5/weather?id=1254694&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 211 Collected at: 2018-02-15 15:28
# City Name: Vailly-sur-Aisne, Country Name: FR
# http://api.openweathermap.org/data/2.5/weather?id=2971169&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 212 Collected at: 2018-02-15 15:28
# City Name: Dinas Powys, Country Name: GB
# http://api.openweathermap.org/data/2.5/weather?id=2651248&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 213 Collected at: 2018-02-15 15:28
# City Name: Legnano, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3174921&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 214 Collected at: 2018-02-15 15:28
# City Name: Newark, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5128639&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 215 Collected at: 2018-02-15 15:28
# City Name: Ahiri, Country Name: IN
# http://api.openweathermap.org/data/2.5/weather?id=1279237&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 216 Collected at: 2018-02-15 15:28
# City Name: Leechburg, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5197568&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 217 Collected at: 2018-02-15 15:28
# City Name: Kyotera, Country Name: UG
# http://api.openweathermap.org/data/2.5/weather?id=230256&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 218 Collected at: 2018-02-15 15:28
# City Name: Jima Abajo, Country Name: DO
# http://api.openweathermap.org/data/2.5/weather?id=3504080&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 219 Collected at: 2018-02-15 15:28
# City Name: Grobzig, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2917206&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 220 Collected at: 2018-02-15 15:28
# City Name: Dornstadt, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2935647&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 221 Collected at: 2018-02-15 15:28
# City Name: Castiglione delle Stiviere, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3179415&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 222 Collected at: 2018-02-15 15:28
# City Name: Ranapur, Country Name: IN
# http://api.openweathermap.org/data/2.5/weather?id=1258537&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 223 Collected at: 2018-02-15 15:28
# City Name: Euxton, Country Name: GB
# http://api.openweathermap.org/data/2.5/weather?id=2649852&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 224 Collected at: 2018-02-15 15:28
# City Name: Vikindu, Country Name: TZ
# http://api.openweathermap.org/data/2.5/weather?id=148987&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 225 Collected at: 2018-02-15 15:28
# City Name: Otley, Country Name: GB
# http://api.openweathermap.org/data/2.5/weather?id=2640857&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 226 Collected at: 2018-02-15 15:28
# City Name: Glenpool, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4537641&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 227 Collected at: 2018-02-15 15:28
# City Name: Eirinoupoli, Country Name: GR
# http://api.openweathermap.org/data/2.5/weather?id=865238&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 228 Collected at: 2018-02-15 15:28
# City Name: Vallensbaek, Country Name: DK
# http://api.openweathermap.org/data/2.5/weather?id=2610789&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 229 Collected at: 2018-02-15 15:28
# City Name: Glevakha, Country Name: UA
# http://api.openweathermap.org/data/2.5/weather?id=708784&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 230 Collected at: 2018-02-15 15:28
# City Name: Van Horn, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5532924&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 231 Collected at: 2018-02-15 15:28
# City Name: Targu Ocna, Country Name: RO
# ...
# http://api.openweathermap.org/data/2.5/weather?id=4919798&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 425 Collected at: 2018-02-15 15:29
# City Name: Kessingland, Country Name: GB
# http://api.openweathermap.org/data/2.5/weather?id=2645761&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 426 Collected at: 2018-02-15 15:29
# City Name: Derwood, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4353084&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 427 Collected at: 2018-02-15 15:29
# City Name: Gojo, Country Name: JP
# http://api.openweathermap.org/data/2.5/weather?id=1863592&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 428 Collected at: 2018-02-15 15:29
# City Name: Zoutleeuw, Country Name: BE
# http://api.openweathermap.org/data/2.5/weather?id=2783170&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 429 Collected at: 2018-02-15 15:29
# City Name: Doddington, Country Name: GB
# http://api.openweathermap.org/data/2.5/weather?id=2651181&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 430 Collected at: 2018-02-15 15:29
# City Name: Roccamonfina, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3169165&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 431 Collected at: 2018-02-15 15:29
# City Name: Bechet, Country Name: RO
# http://api.openweathermap.org/data/2.5/weather?id=685218&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 432 Collected at: 2018-02-15 15:29
# City Name: San Cosme, Country Name: AR
# http://api.openweathermap.org/data/2.5/weather?id=3429157&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 433 Collected at: 2018-02-15 15:29
# City Name: Santa Maria, Country Name: CV
# http://api.openweathermap.org/data/2.5/weather?id=3374218&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 434 Collected at: 2018-02-15 15:29
# City Name: Wharton, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5106361&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 435 Collected at: 2018-02-15 15:29
# City Name: Neuf-Brisach, Country Name: FR
# http://api.openweathermap.org/data/2.5/weather?id=2990683&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 436 Collected at: 2018-02-15 15:29
# City Name: Ferrandina, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3177094&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 437 Collected at: 2018-02-15 15:29
# City Name: Satrup, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2841320&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 438 Collected at: 2018-02-15 15:29
# City Name: Kaya, Country Name: BF
# http://api.openweathermap.org/data/2.5/weather?id=2359608&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 439 Collected at: 2018-02-15 15:29
# City Name: Cotmeana, Country Name: RO
# http://api.openweathermap.org/data/2.5/weather?id=680496&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 440 Collected at: 2018-02-15 15:29
# City Name: Pabellon de Hidalgo, Country Name: MX
# http://api.openweathermap.org/data/2.5/weather?id=3993984&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 441 Collected at: 2018-02-15 15:29
# City Name: Chechen-Aul, Country Name: RU
# http://api.openweathermap.org/data/2.5/weather?id=569666&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 442 Collected at: 2018-02-15 15:29
# City Name: Kauniainen, Country Name: FI
# http://api.openweathermap.org/data/2.5/weather?id=653559&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 443 Collected at: 2018-02-15 15:29
# City Name: La Fria, Country Name: VE
# http://api.openweathermap.org/data/2.5/weather?id=3795152&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 444 Collected at: 2018-02-15 15:29
# City Name: Andravida, Country Name: GR
# http://api.openweathermap.org/data/2.5/weather?id=265056&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 445 Collected at: 2018-02-15 15:29
# City Name: Sabnova, Country Name: RU
# http://api.openweathermap.org/data/2.5/weather?id=499649&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 446 Collected at: 2018-02-15 15:29
# City Name: Axintele, Country Name: RO
# http://api.openweathermap.org/data/2.5/weather?id=686006&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 447 Collected at: 2018-02-15 15:29
# City Name: Fichtenwalde, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2926941&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 448 Collected at: 2018-02-15 15:29
# City Name: Much, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2868936&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 449 Collected at: 2018-02-15 15:29
# City Name: Khovu-Aksy, Country Name: RU
# http://api.openweathermap.org/data/2.5/weather?id=1503527&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 450 Collected at: 2018-02-15 15:29
# City Name: Faulbach, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2927726&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 451 Collected at: 2018-02-15 15:29
# City Name: Wolkenstein, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2806474&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 452 Collected at: 2018-02-15 15:29
# City Name: Sogndal, Country Name: NO
# http://api.openweathermap.org/data/2.5/weather?id=7288345&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 453 Collected at: 2018-02-15 15:29
# City Name: Omagari, Country Name: JP
# http://api.openweathermap.org/data/2.5/weather?id=2111435&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 454 Collected at: 2018-02-15 15:29
# City Name: Raghudebbati, Country Name: IN
# http://api.openweathermap.org/data/2.5/weather?id=1348789&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 455 Collected at: 2018-02-15 15:29
# City Name: Olivia, Country Name: MU
# http://api.openweathermap.org/data/2.5/weather?id=934225&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 456 Collected at: 2018-02-15 15:29
# City Name: Hsinchu, Country Name: TW
# http://api.openweathermap.org/data/2.5/weather?id=1675151&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 457 Collected at: 2018-02-15 15:29
# City Name: Stafford, Country Name: GB
# http://api.openweathermap.org/data/2.5/weather?id=2637142&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 458 Collected at: 2018-02-15 15:29
# City Name: Lahr, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2881885&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 459 Collected at: 2018-02-15 15:29
# City Name: Kodinar, Country Name: IN
# http://api.openweathermap.org/data/2.5/weather?id=1266397&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 460 Collected at: 2018-02-15 15:29
# City Name: Lisbon, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4969622&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 461 Collected at: 2018-02-15 15:29
# City Name: Cadiz, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4286479&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 462 Collected at: 2018-02-15 15:29
# City Name: Saba, Country Name: GM
# http://api.openweathermap.org/data/2.5/weather?id=2412252&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 463 Collected at: 2018-02-15 15:29
# City Name: Santa Rosa, Country Name: AR
# http://api.openweathermap.org/data/2.5/weather?id=3428182&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 464 Collected at: 2018-02-15 15:29
# City Name: Mazeres, Country Name: FR
# http://api.openweathermap.org/data/2.5/weather?id=2994870&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 465 Collected at: 2018-02-15 15:29
# City Name: Otis Orchards-East Farms, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=7262053&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 466 Collected at: 2018-02-15 15:29
# City Name: Lohe-Rickelshof, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=3208554&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 467 Collected at: 2018-02-15 15:29
# City Name: Stevens Point, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=5274644&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 468 Collected at: 2018-02-15 15:29
# City Name: Drensteinfurt, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2935042&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 469 Collected at: 2018-02-15 15:29
# City Name: Jelgava, Country Name: LV
# http://api.openweathermap.org/data/2.5/weather?id=459279&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 470 Collected at: 2018-02-15 15:29
# City Name: Boromo, Country Name: BF
# http://api.openweathermap.org/data/2.5/weather?id=2362150&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 471 Collected at: 2018-02-15 15:29
# City Name: Tudela de Duero, Country Name: ES
# http://api.openweathermap.org/data/2.5/weather?id=3107415&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 472 Collected at: 2018-02-15 15:29
# City Name: Nagireddipalli, Country Name: IN
# http://api.openweathermap.org/data/2.5/weather?id=1262196&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 473 Collected at: 2018-02-15 15:29
# City Name: Frassinoro, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3176573&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 474 Collected at: 2018-02-15 15:29
# City Name: Cherry Hill, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4501198&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 475 Collected at: 2018-02-15 15:29
# City Name: Kabinda, Country Name: CD
# http://api.openweathermap.org/data/2.5/weather?id=215527&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 476 Collected at: 2018-02-15 15:29
# City Name: Hannahs Mill, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4199055&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 477 Collected at: 2018-02-15 15:29
# City Name: Bhatpara Abhaynagar, Country Name: BD
# http://api.openweathermap.org/data/2.5/weather?id=1185260&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 478 Collected at: 2018-02-15 15:29
# City Name: Lauenburg, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2880181&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 479 Collected at: 2018-02-15 15:29
# City Name: Ag-ambulong, Country Name: PH
# http://api.openweathermap.org/data/2.5/weather?id=1732191&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 480 Collected at: 2018-02-15 15:29
# City Name: Nienburg, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2862621&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 481 Collected at: 2018-02-15 15:29
# City Name: Peso da Regua, Country Name: PT
# http://api.openweathermap.org/data/2.5/weather?id=2736316&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 482 Collected at: 2018-02-15 15:29
# City Name: Vogelsen, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2816874&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 483 Collected at: 2018-02-15 15:29
# City Name: Carbonne, Country Name: FR
# http://api.openweathermap.org/data/2.5/weather?id=3028652&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 484 Collected at: 2018-02-15 15:29
# City Name: Iba, Country Name: PH
# http://api.openweathermap.org/data/2.5/weather?id=1711436&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 485 Collected at: 2018-02-15 15:29
# City Name: Gibraltar, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4993873&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 486 Collected at: 2018-02-15 15:29
# City Name: Vyssi Brod, Country Name: CZ
# http://api.openweathermap.org/data/2.5/weather?id=3062184&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 487 Collected at: 2018-02-15 15:29
# City Name: Pipirig, Country Name: RO
# http://api.openweathermap.org/data/2.5/weather?id=670777&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 488 Collected at: 2018-02-15 15:29
# City Name: Lacedonia, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=3175334&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 489 Collected at: 2018-02-15 15:29
# City Name: Strba, Country Name: SK
# http://api.openweathermap.org/data/2.5/weather?id=723468&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 490 Collected at: 2018-02-15 15:29
# City Name: Dijkot, Country Name: PK
# http://api.openweathermap.org/data/2.5/weather?id=1179834&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 491 Collected at: 2018-02-15 15:29
# City Name: Jacksboro, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4700455&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 492 Collected at: 2018-02-15 15:29
# City Name: Bodenwohr, Country Name: DE
# http://api.openweathermap.org/data/2.5/weather?id=2947090&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 493 Collected at: 2018-02-15 15:29
# City Name: San Jacinto, Country Name: PH
# http://api.openweathermap.org/data/2.5/weather?id=1689603&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 494 Collected at: 2018-02-15 15:29
# City Name: Safety Harbor, Country Name: US
# http://api.openweathermap.org/data/2.5/weather?id=4170797&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 495 Collected at: 2018-02-15 15:29
# City Name: Resuttano, Country Name: IT
# http://api.openweathermap.org/data/2.5/weather?id=2523622&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 496 Collected at: 2018-02-15 15:29
# City Name: Al Khankah, Country Name: EG
# http://api.openweathermap.org/data/2.5/weather?id=360928&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 497 Collected at: 2018-02-15 15:29
# City Name: Novska, Country Name: HR
# http://api.openweathermap.org/data/2.5/weather?id=3194319&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 498 Collected at: 2018-02-15 15:29
# City Name: Villemoisson-sur-Orge, Country Name: FR
# http://api.openweathermap.org/data/2.5/weather?id=2968655&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 499 Collected at: 2018-02-15 15:29
# City Name: Nugas, Country Name: PH
# http://api.openweathermap.org/data/2.5/weather?id=1697447&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# Record 500 Collected at: 2018-02-15 15:29
# City Name: Bagumbayan, Country Name: PH
# http://api.openweathermap.org/data/2.5/weather?id=1728902&units=imperial&APPID=0c715aff73757bce5f32aba6da14fd45
# --------------
# ------End Collecting Data------

# %%
#Check that dataframe has been populated with data from the query

city_df.head()
# Out:
#    city_id                                                url  \
# 0  2164206  http://api.openweathermap.org/data/2.5/weather...
# 1  3085019  http://api.openweathermap.org/data/2.5/weather...
# 2  2612274  http://api.openweathermap.org/data/2.5/weather...
# 3  2880228  http://api.openweathermap.org/data/2.5/weather...
# 4   295370  http://api.openweathermap.org/data/2.5/weather...
#
#               city country    lat     lon   temp   wind clouds humidity
# 0         Gunnedah      AU -30.98  150.25   84.2   1.12      0       13
# 1  Stanislaw Dolny      PL   49.9   19.65   26.6   3.36     48       86
# 2         Strandby      DK  57.49    10.5  36.94  12.21     48       98
# 3           Laucha      DE  51.22   11.68   35.6  10.29     90       88
# 4        Dabburiya      IL  32.69   35.37  41.53   2.93      0       86

# %%
city_df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>city_id</th>\n      <th>url</th>\n      <th>city</th>\n      <th>country</th>\n      <th>lat</th>\n      <th>lon</th>\n      <th>temp</th>\n      <th>wind</th>\n      <th>clouds</th>\n      <th>humidity</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>2164206</td>\n      <td>http://api.openweathermap.org/data/2.5/weather...</td>\n      <td>Gunnedah</td>\n      <td>AU</td>\n      <td>-30.98</td>\n      <td>150.25</td>\n      <td>84.2</td>\n      <td>1.12</td>\n      <td>0</td>\n      <td>13</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>3085019</td>\n      <td>http://api.openweathermap.org/data/2.5/weather...</td>\n      <td>Stanislaw Dolny</td>\n      <td>PL</td>\n      <td>49.9</td>\n      <td>19.65</td>\n      <td>26.6</td>\n      <td>3.36</td>\n      <td>48</td>\n      <td>86</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2612274</td>\n      <td>http://api.openweathermap.org/data/2.5/weather...</td>\n      <td>Strandby</td>\n      <td>DK</td>\n      <td>57.49</td>\n      <td>10.5</td>\n      <td>36.94</td>\n      <td>12.21</td>\n      <td>48</td>\n      <td>98</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>2880228</td>\n      <td>http://api.openweathermap.org/data/2.5/weather...</td>\n      <td>Laucha</td>\n      <td>DE</td>\n      <td>51.22</td>\n      <td>11.68</td>\n      <td>35.6</td>\n      <td>10.29</td>\n      <td>90</td>\n      <td>88</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>295370</td>\n      <td>http://api.openweathermap.org/data/2.5/weather...</td>\n      <td>Dabburiya</td>\n      <td>IL</td>\n      <td>32.69</td>\n      <td>35.37</td>\n      <td>41.53</td>\n      <td>2.93</td>\n      <td>0</td>\n      <td>86</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>3170754</td>\n      <td>http://api.openweathermap.org/data/2.5/weather...</td>\n      <td>Pieve di Cadore</td>\n      <td>IT</td>\n      <td>46.43</td>\n      <td>12.38</td>\n      <td>21.28</td>\n      <td>2.93</td>\n      <td>0</td>\n      <td>74</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>158904</td>\n      <td>http://api.openweathermap.org/data/2.5/weather...</td>\n      <td>Itigi</td>\n      <td>TZ</td>\n      <td>-5.7</td>\n      <td>34.48</td>\n      <td>66.41</td>\n      <td>10.2</td>\n      <td>0</td>\n      <td>67</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>292223</td>\n      <td>http://api.openweathermap.org/data/2.5/weather...</td>\n      <td>Dubai</td>\n      <td>AE</td>\n      <td>25.26</td>\n      <td>55.3</td>\n      <td>75.2</td>\n      <td>4.7</td>\n      <td>0</td>\n      <td>53</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>3601282</td>\n      <td>http://api.openweathermap.org/data/2.5/weather...</td>\n      <td>Sinuapa</td>\n      <td>HN</td>\n      <td>14.45</td>\n      <td>-89.18</td>\n      <td>89.6</td>\n      <td>12.75</td>\n      <td>20</td>\n      <td>25</td>\n    </tr>\n    <tr>\n      <th>9</th>\n      <td>1784953</td>\n      <td>http://api.openweathermap.org/data/2.5/weather...</td>\n      <td>Zhaoyuan</td>\n      <td>CN</td>\n      <td>37.36</td>\n      <td>120.4</td>\n      <td>21.68</td>\n      <td>4.61</td>\n      <td>0</td>\n      <td>74</td>\n    </tr>\n    <tr>\n      <th>10</th>\n      <td>3491905</td>\n      <td>http://api.openweathermap.org/data/2.5/weather...</td>\n      <td>Villa Vasquez</td>\n      <td>DO</td>\n      <td>19.74</td>\n      <td>-71.45</td>\n      <td>76.31</td>\n      <td>20.38</td>\n      <td>0</td>\n      <td>75</td>\n    </tr>\n    <tr>\n      <th>11</th>\n      <td>2523613</td>\n      <td>http://api.openweathermap.org/data/2.5/weather...</td>\n      <td>Riola Sardo</td>\n      <td>IT</td>\n      <td>40</td>\n      <td>8.54</td>\n      <td>45.53</td>\n      <td>2.15</td>\n      <td>24</td>\n      <td>94</td>\n    </tr>\n    <tr>\n      <th>12</th>\n      <td>3172115</td>\n      <td>http ...

# %%
#Export complete dataframe to a csv file.

city_df.to_csv('hw6_export.csv')

# %%
#Check shape of dataframe to confirm that all values have been collected.

city_df.shape
# Out:
# (500, 10)

# %%
#Develop function to generate lists needed to plot data

def plot_data(c):
    city_lat_list = c['lat'].tolist()
    city_temp_list = c['temp'].tolist()
    city_humidity_list = c['humidity'].tolist()
    city_windspeed_list = c['wind'].tolist()
    city_cloud_list = c['clouds'].tolist()
    return city_lat_list, city_temp_list, city_humidity_list, city_windspeed_list, city_cloud_list

# %%
#Generate first plot of temp vs position.

plt.figure(figsize=(10,10))
plt.scatter(plot_data(city_df)[0], plot_data(city_df)[1], color='b', alpha = 1, edgecolors='black', linewidths=1)
plt.xlabel("Latitude (deg)" ,fontsize = 14)
plt.ylabel("Max. Temperature (F)", fontsize = 14)
plt.title("Max. Temperature vs Latitude (12/16/2017)", fontsize = 14)
plt.xlim(-80, 100, 10)
plt.ylim(-20, 120, 10)
plt.grid(True)
plt.show()

# %%
#Generate second plot of wind speed vs position.

plt.figure(figsize=(10,10))
plt.scatter(plot_data(city_df)[0], plot_data(city_df)[3], color='b', alpha = 1, edgecolors='black', linewidths=1)
plt.xlabel("Latitude (deg)" ,fontsize = 14)
plt.ylabel("Windspeed (mph)", fontsize = 14)
plt.title("Windspeed vs Latitude (12/16/2017)", fontsize = 14)
plt.xlim(-80, 100, 10)
plt.ylim(0, 25, 10)
plt.grid(True)
plt.show()

# %%
#Generate third plot of humidity vs position.

plt.figure(figsize=(10,10))
plt.scatter(plot_data(city_df)[0], plot_data(city_df)[2], color='b', alpha = 1, edgecolors='black', linewidths=1)
plt.xlabel("Latitude (deg)" ,fontsize = 14)
plt.ylabel("Humidity (%)", fontsize = 14)
plt.title("Humidity vs Latitude (12/16/2017)", fontsize = 14)
plt.xlim(-80, 100, 10)
plt.ylim(0, 120, 10)
plt.grid(True)
plt.show()

# %%
#Generate first plot of cloudiness vs position.

plt.figure(figsize=(10,10))
plt.scatter(plot_data(city_df)[0], plot_data(city_df)[4], color='b', alpha = 1, edgecolors='black', linewidths=1)
plt.xlabel("Latitude (deg)" ,fontsize = 14)
plt.ylabel("Cloudiness (%)", fontsize = 14)
plt.title("Cloudiness vs Latitude (12/16/2017)", fontsize = 14)
plt.xlim(-80, 100, 10)
plt.ylim(-20, 120, 10)
plt.grid(True)
plt.show()

# %% [markdown]
# ***
# GTA (2017-12-17)
