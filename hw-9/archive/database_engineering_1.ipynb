# %% [markdown]
# ## Step 2 - Database Engineering
#
# Use SQLAlchemy to model your table schemas and create a sqlite database for your tables. You will need one table for measurements and one for stations.
#
# * Create a Jupyter Notebook called `database_engineering.ipynb` and use this to complete all of your Database Engineering work.
#
# * Use Pandas to read your cleaned measurements and stations CSV data.
#
# * Use the `engine` and connection string to create a database called `hawaii.sqlite`.
#
# * Use `declarative_base` and create ORM classes for each table.
#
#   * You will need a class for `Measurement` and for `Station`.
#
#   * Make sure to define your primary keys.
#
# * Once you have your ORM classes defined, create the tables in the database using `create_all`.
#
# ---

# %%
# !rm hawaii.sqlite

# %%
import sqlalchemy
import pandas as pd
from sqlalchemy import create_engine, MetaData
#from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Numeric, Text, Float, DateTime

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# %%
conn = engine.connect()

# %%
Base = declarative_base()

# %%
class Data(Base):
    __tablename__ = 'hawaii_data'
    id = Column(Integer, primary_key=True)
    station = Column(String)
    name = Column(String)
    latitude = Column(Float)
    longitude = Column(Float)
    elevation = Column(Integer)
    prcp = Column(Float)
    tobs = Column(Integer)
    month = Column(Integer)
    day = Column(Integer)
    year = Column(Integer)
    date_format = Column(DateTime)
    
    #def __repr__(self):
    #   return f"id={self.id}, name={self.name}"

    #Error - “SQLite DateTime type only accepts Python ” “datetime and date objects as input.”
    #http://docs.sqlalchemy.org/en/latest/dialects/sqlite.html
    #https://stackoverflow.com/questions/38067704/how-to-change-the-datetime-format-in-pandas

# %%
Base.metadata.create_all(engine)

# %%
data = pd.read_csv('data.csv')

# %%
#data.head()

# %%
data['date_object'] = pd.to_datetime(data['date_format'])

# %%
#data.head()

# %%
del data['date_format']

# %%
#data.info()

# %%
data_dict = data.to_dict(orient='records')
data_dict
# Out:
# [{'date_object': Timestamp('2010-01-01 00:00:00'),
#   'day': 1,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.08,
#   'station': 'USC00519397',
#   'tobs': 65,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-02 00:00:00'),
#   'day': 2,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 63,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-03 00:00:00'),
#   'day': 3,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 74,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-04 00:00:00'),
#   'day': 4,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-06 00:00:00'),
#   'day': 6,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.040085836909871206,
#   'station': 'USC00519397',
#   'tobs': 73,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-07 00:00:00'),
#   'day': 7,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.06,
#   'station': 'USC00519397',
#   'tobs': 70,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-08 00:00:00'),
#   'day': 8,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 64,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-09 00:00:00'),
#   'day': 9,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 68,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-10 00:00:00'),
#   'day': 10,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 73,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-11 00:00:00'),
#   'day': 11,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 64,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-12 00:00:00'),
#   'day': 12,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 61,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-14 00:00:00'),
#   'day': 14,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 66,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-15 00:00:00'),
#   'day': 15,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 65,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-16 00:00:00'),
#   'day': 16,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 68,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-17 00:00:00'),
#   'day': 17,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 64,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-18 00:00:00'),
#   'day': 18,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 72,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-19 00:00:00'),
#   'day': 19,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 66,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-20 00:00:00'),
#   'day': 20,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 66,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-21 00:00:00'),
#   'day': 21,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 69,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-22 00:00:00'),
#   'day': 22,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 67,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-23 00:00:00'),
#   'day': 23,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 67,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-24 00:00:00'),
#   'day': 24,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 71,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-25 00:00:00'),
#   'day': 25,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 67,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-26 00:00:00'),
#   'day': 26,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.04,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-27 00:00:00'),
#   'day': 27,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.12,
#   'station': 'USC00519397',
#   'tobs': 68,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-28 00:00:00'),
#   'day': 28,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 72,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-30 00:00:00'),
#   'day': 30,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.040085836909871206,
#   'station': 'USC00519397',
#   'tobs': 70,
#   'year': 2010},
#  {'date_object': Timestamp('2010-01-31 00:00:00'),
#   'day': 31,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 1,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.03,
#   'station': 'USC00519397',
#   'tobs': 67,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-01 00:00:00'),
#   'day': 1,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 66,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-03 00:00:00'),
#   'day': 3,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0673611111111111,
#   'station': 'USC00519397',
#   'tobs': 67,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-04 00:00:00'),
#   'day': 4,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 69,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-05 00:00:00'),
#   'day': 5,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 67,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-06 00:00:00'),
#   'day': 6,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 67,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-07 00:00:00'),
#   'day': 7,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 64,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-08 00:00:00'),
#   'day': 8,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 69,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-09 00:00:00'),
#   'day': 9,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 73,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-11 00:00:00'),
#   'day': 11,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 73,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-12 00:00:00'),
#   'day': 12,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.02,
#   'station': 'USC00519397',
#   'tobs': 69,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-13 00:00:00'),
#   'day': 13,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 69,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-14 00:00:00'),
#   'day': 14,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 69,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-15 00:00:00'),
#   'day': 15,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 71,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-16 00:00:00'),
#   'day': 16,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 61,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-17 00:00:00'),
#   'day': 17,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 69,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-19 00:00:00'),
#   'day': 19,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0673611111111111,
#   'station': 'USC00519397',
#   'tobs': 63,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-20 00:00:00'),
#   'day': 20,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.03,
#   'station': 'USC00519397',
#   'tobs': 64,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-21 00:00:00'),
#   'day': 21,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 65,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-22 00:00:00'),
#   'day': 22,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 67,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-23 00:00:00'),
#   'day': 23,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 68,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-24 00:00:00'),
#   'day': 24,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 65,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-25 00:00:00'),
#   'day': 25,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-26 00:00:00'),
#   'day': 26,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2010},
#  {'date_object': Timestamp('2010-02-28 00:00:00'),
#   'day': 28,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 2,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 66,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-01 00:00:00'),
#   'day': 1,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 70,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-02 00:00:00'),
#   'day': 2,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 72,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-03 00:00:00'),
#   'day': 3,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 73,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-04 00:00:00'),
#   'day': 4,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.12,
#   'station': 'USC00519397',
#   'tobs': 70,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-05 00:00:00'),
#   'day': 5,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.08,
#   'station': 'USC00519397',
#   'tobs': 71,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-06 00:00:00'),
#   'day': 6,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.03,
#   'station': 'USC00519397',
#   'tobs': 72,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-07 00:00:00'),
#   'day': 7,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 72,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-08 00:00:00'),
#   'day': 8,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.43,
#   'station': 'USC00519397',
#   'tobs': 69,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-09 00:00:00'),
#   'day': 9,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.06,
#   'station': 'USC00519397',
#   'tobs': 70,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-11 00:00:00'),
#   'day': 11,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0890128755364807,
#   'station': 'USC00519397',
#   'tobs': 73,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-12 00:00:00'),
#   'day': 12,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 72,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-13 00:00:00'),
#   'day': 13,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 73,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-14 00:00:00'),
#   'day': 14,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 70,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-15 00:00:00'),
#   'day': 15,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.06,
#   'station': 'USC00519397',
#   'tobs': 71,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-17 00:00:00'),
#   'day': 17,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 68,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-18 00:00:00'),
#   'day': 18,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 70,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-21 00:00:00'),
#   'day': 21,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 72,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-22 00:00:00'),
#   'day': 22,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 69,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-23 00:00:00'),
#   'day': 23,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 68,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-24 00:00:00'),
#   'day': 24,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 74,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-26 00:00:00'),
#   'day': 26,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0890128755364807,
#   'station': 'USC00519397',
#   'tobs': 72,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-27 00:00:00'),
#   'day': 27,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 72,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-28 00:00:00'),
#   'day': 28,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 73,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-29 00:00:00'),
#   'day': 29,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 74,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-30 00:00:00'),
#   'day': 30,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 73,
#   'year': 2010},
#  {'date_object': Timestamp('2010-03-31 00:00:00'),
#   'day': 31,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 3,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 73,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-01 00:00:00'),
#   'day': 1,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 74,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-02 00:00:00'),
#   'day': 2,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 74,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-03 00:00:00'),
#   'day': 3,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.17,
#   'station': 'USC00519397',
#   'tobs': 74,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-04 00:00:00'),
#   'day': 4,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.15,
#   'station': 'USC00519397',
#   'tobs': 71,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-05 00:00:00'),
#   'day': 5,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.27,
#   'station': 'USC00519397',
#   'tobs': 72,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-06 00:00:00'),
#   'day': 6,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-08 00:00:00'),
#   'day': 8,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-09 00:00:00'),
#   'day': 9,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-10 00:00:00'),
#   'day': 10,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-11 00:00:00'),
#   'day': 11,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 73,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-12 00:00:00'),
#   'day': 12,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 73,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-13 00:00:00'),
#   'day': 13,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 71,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-15 00:00:00'),
#   'day': 15,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 71,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-16 00:00:00'),
#   'day': 16,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 68,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-17 00:00:00'),
#   'day': 17,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 70,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-18 00:00:00'),
#   'day': 18,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 71,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-19 00:00:00'),
#   'day': 19,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 74,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-20 00:00:00'),
#   'day': 20,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.04,
#   'station': 'USC00519397',
#   'tobs': 71,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-21 00:00:00'),
#   'day': 21,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-22 00:00:00'),
#   'day': 22,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-23 00:00:00'),
#   'day': 23,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.02,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-24 00:00:00'),
#   'day': 24,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-25 00:00:00'),
#   'day': 25,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-26 00:00:00'),
#   'day': 26,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-28 00:00:00'),
#   'day': 28,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-04-30 00:00:00'),
#   'day': 30,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 4,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-01 00:00:00'),
#   'day': 1,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-02 00:00:00'),
#   'day': 2,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.03,
#   'station': 'USC00519397',
#   'tobs': 73,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-03 00:00:00'),
#   'day': 3,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.2,
#   'station': 'USC00519397',
#   'tobs': 74,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-04 00:00:00'),
#   'day': 4,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.08,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-05 00:00:00'),
#   'day': 5,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-06 00:00:00'),
#   'day': 6,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 80,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-07 00:00:00'),
#   'day': 7,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.05,
#   'station': 'USC00519397',
#   'tobs': 74,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-08 00:00:00'),
#   'day': 8,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-09 00:00:00'),
#   'day': 9,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-10 00:00:00'),
#   'day': 10,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-11 00:00:00'),
#   'day': 11,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-13 00:00:00'),
#   'day': 13,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-14 00:00:00'),
#   'day': 14,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-15 00:00:00'),
#   'day': 15,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-16 00:00:00'),
#   'day': 16,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.03,
#   'station': 'USC00519397',
#   'tobs': 73,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-17 00:00:00'),
#   'day': 17,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-18 00:00:00'),
#   'day': 18,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-19 00:00:00'),
#   'day': 19,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-21 00:00:00'),
#   'day': 21,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.04020833333333332,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-22 00:00:00'),
#   'day': 22,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-23 00:00:00'),
#   'day': 23,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.05,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-24 00:00:00'),
#   'day': 24,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-25 00:00:00'),
#   'day': 25,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-26 00:00:00'),
#   'day': 26,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.02,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-27 00:00:00'),
#   'day': 27,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-28 00:00:00'),
#   'day': 28,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-29 00:00:00'),
#   'day': 29,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-30 00:00:00'),
#   'day': 30,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-05-31 00:00:00'),
#   'day': 31,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 5,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-01 00:00:00'),
#   'day': 1,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-02 00:00:00'),
#   'day': 2,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-03 00:00:00'),
#   'day': 3,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-04 00:00:00'),
#   'day': 4,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-05 00:00:00'),
#   'day': 5,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-06 00:00:00'),
#   'day': 6,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-07 00:00:00'),
#   'day': 7,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-08 00:00:00'),
#   'day': 8,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-09 00:00:00'),
#   'day': 9,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-10 00:00:00'),
#   'day': 10,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 79,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-11 00:00:00'),
#   'day': 11,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-12 00:00:00'),
#   'day': 12,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-13 00:00:00'),
#   'day': 13,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-14 00:00:00'),
#   'day': 14,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-15 00:00:00'),
#   'day': 15,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-16 00:00:00'),
#   'day': 16,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-17 00:00:00'),
#   'day': 17,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-18 00:00:00'),
#   'day': 18,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-19 00:00:00'),
#   'day': 19,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 82,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-20 00:00:00'),
#   'day': 20,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-21 00:00:00'),
#   'day': 21,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-22 00:00:00'),
#   'day': 22,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-23 00:00:00'),
#   'day': 23,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-24 00:00:00'),
#   'day': 24,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-25 00:00:00'),
#   'day': 25,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-26 00:00:00'),
#   'day': 26,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.02,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-27 00:00:00'),
#   'day': 27,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-28 00:00:00'),
#   'day': 28,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-29 00:00:00'),
#   'day': 29,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-06-30 00:00:00'),
#   'day': 30,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 6,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-01 00:00:00'),
#   'day': 1,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-02 00:00:00'),
#   'day': 2,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.05,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-03 00:00:00'),
#   'day': 3,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.09,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-04 00:00:00'),
#   'day': 4,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.05,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-05 00:00:00'),
#   'day': 5,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.06,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-06 00:00:00'),
#   'day': 6,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.08,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-07 00:00:00'),
#   'day': 7,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.08,
#   'station': 'USC00519397',
#   'tobs': 74,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-08 00:00:00'),
#   'day': 8,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.03,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-09 00:00:00'),
#   'day': 9,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.06,
#   'station': 'USC00519397',
#   'tobs': 74,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-10 00:00:00'),
#   'day': 10,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.09,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-11 00:00:00'),
#   'day': 11,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-12 00:00:00'),
#   'day': 12,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-13 00:00:00'),
#   'day': 13,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 80,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-16 00:00:00'),
#   'day': 16,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.048368200836820065,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-17 00:00:00'),
#   'day': 17,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.02,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-18 00:00:00'),
#   'day': 18,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-19 00:00:00'),
#   'day': 19,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.04,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-21 00:00:00'),
#   'day': 21,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 80,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-22 00:00:00'),
#   'day': 22,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-24 00:00:00'),
#   'day': 24,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 80,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-25 00:00:00'),
#   'day': 25,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 79,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-26 00:00:00'),
#   'day': 26,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-27 00:00:00'),
#   'day': 27,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 79,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-28 00:00:00'),
#   'day': 28,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2010},
#  {'date_object': Timestamp('2010-07-29 00:00:00'),
#   'day': 29,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 7,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
# ...
#   'month': 9,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.04,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2012},
#  {'date_object': Timestamp('2012-09-24 00:00:00'),
#   'day': 24,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 9,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2012},
#  {'date_object': Timestamp('2012-09-25 00:00:00'),
#   'day': 25,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 9,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2012},
#  {'date_object': Timestamp('2012-09-26 00:00:00'),
#   'day': 26,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 9,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2012},
#  {'date_object': Timestamp('2012-09-27 00:00:00'),
#   'day': 27,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 9,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.02,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2012},
#  {'date_object': Timestamp('2012-09-28 00:00:00'),
#   'day': 28,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 9,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2012},
#  {'date_object': Timestamp('2012-09-29 00:00:00'),
#   'day': 29,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 9,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2012},
#  {'date_object': Timestamp('2012-09-30 00:00:00'),
#   'day': 30,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 9,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.02,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-01 00:00:00'),
#   'day': 1,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-02 00:00:00'),
#   'day': 2,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 74,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-03 00:00:00'),
#   'day': 3,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-04 00:00:00'),
#   'day': 4,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-05 00:00:00'),
#   'day': 5,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 73,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-06 00:00:00'),
#   'day': 6,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.03,
#   'station': 'USC00519397',
#   'tobs': 73,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-07 00:00:00'),
#   'day': 7,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-08 00:00:00'),
#   'day': 8,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-09 00:00:00'),
#   'day': 9,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-10 00:00:00'),
#   'day': 10,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-11 00:00:00'),
#   'day': 11,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 80,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-12 00:00:00'),
#   'day': 12,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-13 00:00:00'),
#   'day': 13,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 79,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-14 00:00:00'),
#   'day': 14,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-15 00:00:00'),
#   'day': 15,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.02,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-16 00:00:00'),
#   'day': 16,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-17 00:00:00'),
#   'day': 17,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 72,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-18 00:00:00'),
#   'day': 18,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-19 00:00:00'),
#   'day': 19,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-20 00:00:00'),
#   'day': 20,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-21 00:00:00'),
#   'day': 21,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-22 00:00:00'),
#   'day': 22,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-23 00:00:00'),
#   'day': 23,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-24 00:00:00'),
#   'day': 24,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-25 00:00:00'),
#   'day': 25,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-26 00:00:00'),
#   'day': 26,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-27 00:00:00'),
#   'day': 27,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 74,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-28 00:00:00'),
#   'day': 28,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.02,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-29 00:00:00'),
#   'day': 29,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.04,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-30 00:00:00'),
#   'day': 30,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2012},
#  {'date_object': Timestamp('2012-10-31 00:00:00'),
#   'day': 31,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 10,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.02,
#   'station': 'USC00519397',
#   'tobs': 78,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-01 00:00:00'),
#   'day': 1,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 71,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-02 00:00:00'),
#   'day': 2,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 70,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-03 00:00:00'),
#   'day': 3,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 74,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-04 00:00:00'),
#   'day': 4,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 71,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-05 00:00:00'),
#   'day': 5,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 69,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-06 00:00:00'),
#   'day': 6,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-07 00:00:00'),
#   'day': 7,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-08 00:00:00'),
#   'day': 8,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-09 00:00:00'),
#   'day': 9,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.03,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-10 00:00:00'),
#   'day': 10,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-11 00:00:00'),
#   'day': 11,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-12 00:00:00'),
#   'day': 12,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-13 00:00:00'),
#   'day': 13,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.06,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-14 00:00:00'),
#   'day': 14,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 77,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-15 00:00:00'),
#   'day': 15,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.08,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-16 00:00:00'),
#   'day': 16,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.03,
#   'station': 'USC00519397',
#   'tobs': 73,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-17 00:00:00'),
#   'day': 17,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.01,
#   'station': 'USC00519397',
#   'tobs': 74,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-18 00:00:00'),
#   'day': 18,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.03,
#   'station': 'USC00519397',
#   'tobs': 76,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-19 00:00:00'),
#   'day': 19,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-20 00:00:00'),
#   'day': 20,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 75,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-21 00:00:00'),
#   'day': 21,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 71,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-22 00:00:00'),
#   'day': 22,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 69,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-23 00:00:00'),
#   'day': 23,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.0,
#   'station': 'USC00519397',
#   'tobs': 71,
#   'year': 2012},
#  {'date_object': Timestamp('2012-11-24 00:00:00'),
#   'day': 24,
#   'elevation': 3.0,
#   'latitude': 21.2716,
#   'longitude': -157.8168,
#   'month': 11,
#   'name': 'WAIKIKI 717.2, HI US',
#   'prcp': 0.02,
#   'station': 'USC00519397',
#   'tobs': 69,
#   'year': 2012},
#  ...]

# %%
metadata = MetaData(bind = engine)
metadata.reflect()

# %%
table = sqlalchemy.Table('hawaii_data', metadata, autoload=True)

# %%
conn.execute(table.delete())

# %%
conn.execute(table.insert(), data_dict)

# %%
conn.execute("select * FROM hawaii_data limit 5").fetchall()
# Out:
# [(1, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3, 0.08, 65, 1, 1, 2010, None),
#  (2, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3, 0.0, 63, 1, 2, 2010, None),
#  (3, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3, 0.0, 74, 1, 3, 2010, None),
#  (4, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3, 0.0, 76, 1, 4, 2010, None),
#  (5, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3, 0.040085836909871206, 73, 1, 6, 2010, None)]

# %%
"""

    id = Column(Integer, primary_key=True)
    station = Column(String)
    name = Column(String)
    latitude = Column(Float)
    longitude = Column(Float)
    elevation = Column(Integer)
    prcp = Column(Float)
    tobs = Column(Integer)
    month = Column(Integer)
    day = Column(Integer)
    year = Column(Integer)
    date_format = Column(DateTime)

"""
# Out:
# '\n\n    id = Column(Integer, primary_key=True)\n    station = Column(String)\n    name = Column(String)\n    latitude = Column(Float)\n    longitude = Column(Float)\n    elevation = Column(Integer)\n    prcp = Column(Float)\n    tobs = Column(Integer)\n    month = Column(Integer)\n    day = Column(Integer)\n    year = Column(Integer)\n    date_format = Column(DateTime)\n\n'

# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column , Integer
from sqlalchemy.orm import sessionmaker
import pyexcel as pe

engine=create_engine("sqlite:///hawaii.sqlite")
Base=declarative_base()

class Data(Base):
    __tablename__ = 'hawaii_data'
    id = Column(Integer, primary_key=True)
    station = Column(String)
    name = Column(String)
    latitude = Column(Float)
    longitude = Column(Float)
    elevation = Column(Integer)
    prcp = Column(Float)
    tobs = Column(Integer)
    month = Column(Integer)
    day = Column(Integer)
    year = Column(Integer)
    date_format = Column(DateTime)

Session=sessionmaker(bind=engine)
Base.metadata.drop_all(engine)
Base.metadata.create_all(engine)
session = Session()
# produce test csv
data_dict = data_dict

# sheet = pe.get_sheet(data_dict=data_dict)
# sheet.save_as("test.csv")

# pe.save_as(file_name="test.csv", dest_session=session, dest_table=hawaii_data)
result = pe.get_dict(session=session, table=hawaii_data)
# Out:
# ---------------------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-49-c36db492749a> in <module>()
#      34
#      35 # pe.save_as(file_name="test.csv", dest_session=session, dest_table=hawaii_data)
# ---> 36 result = pe.get_dict(session=session, table=hawaii_data)
#
# NameError: name 'hawaii_data' is not defined
